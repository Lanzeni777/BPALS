# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta
import os, sys
import urllib3
import time
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
sys.path.append(os.path.abspath(os.path.join(os.path.dirname("."), '..')))
from DataBase.DBUtilities import BRVMDatabase, DataPreProcessor

# %%
kl_db = BRVMDatabase("KAN.db")
#db.load_available_data()
#??BRVMDatabase

# %%
kl_db.status()
print("\n######### CLEANING ###########\n")
kl_db.clear_table("stock_prices")
kl_db.status()
print("\n######### INSERTION OF HISTORICAL DATA UNTIL 2015 ###########\n")
kl_db.insert_histo_data()
kl_db.status()
print("\n######### INSERTION OF 3 RECENT MONTHS ###########\n")
kl_db.insert_3m_histo_data()
kl_db.status()
print("\n######### CLEINSERTION OF TODAY PRICES ###########\n")
kl_db.insert_daily_prices()
_ = kl_db.status()
# Out:
# Table status (rows):
# capitalisations : 0 rows of ['Ticker', 'Stock_Description', 'Nombre_de_titres', 'Cours_du_jour', 'Capitalisation_flottante', 'Capitalisation_globale', 'Capitalisation_globale_pct', 'Date']
# per_data : 98 rows of ['Ticker', 'Stock_Description', 'Nombre_titres_echanges', 'Valeur_echangee', 'PER', 'Valeur_globale_echangee_pct', 'Date']
# stock_prices : 94005 rows of ['Date', 'Ticker', 'Description', 'Open', 'High', 'Low', 'Close', 'Volume']
# indices_performances : 1122 rows of ['Date', 'Ticker', 'Description', 'Open', 'High', 'Low', 'Close', 'Volume']
#
# ######### CLEANING ###########
#
# Table status (rows):
# capitalisations : 0 rows of ['Ticker', 'Stock_Description', 'Nombre_de_titres', 'Cours_du_jour', 'Capitalisation_flottante', 'Capitalisation_globale', 'Capitalisation_globale_pct', 'Date']
# per_data : 98 rows of ['Ticker', 'Stock_Description', 'Nombre_titres_echanges', 'Valeur_echangee', 'PER', 'Valeur_globale_echangee_pct', 'Date']
# stock_prices : 0 rows of ['Date', 'Ticker', 'Description', 'Open', 'High', 'Low', 'Close', 'Volume']
# indices_performances : 1122 rows of ['Date', 'Ticker', 'Description', 'Open', 'High', 'Low', 'Close', 'Volume']
#
# ######### INSERTION OF HISTORICAL DATA UNTIL 2015 ###########
#
# to add  BICB BANQUE INTERNATIONALE POUR LE COMMERCE DU BENIN
# Data already loaded
# Table status (rows):
# capitalisations : 0 rows of ['Ticker', 'Stock_Description', 'Nombre_de_titres', 'Cours_du_jour', 'Capitalisation_flottante', 'Capitalisation_globale', 'Capitalisation_globale_pct', 'Date']
# per_data : 98 rows of ['Ticker', 'Stock_Description', 'Nombre_titres_echanges', 'Valeur_echangee', 'PER', 'Valeur_globale_echangee_pct', 'Date']
# stock_prices : 93717 rows of ['Date', 'Ticker', 'Description', 'Open', 'High', 'Low', 'Close', 'Volume']
# indices_performances : 1122 rows of ['Date', 'Ticker', 'Description', 'Open', 'High', 'Low', 'Close', 'Volume']
#
# ######### INSERTION OF 3 RECENT MONTHS ###########
#
# Failed to load data for FTSC
# Unknown columns in stock_prices: {'Variation'}
# Inserted 288 new rows into 'prices' table.
# Table status (rows):
# capitalisations : 0 rows of ['Ticker', 'Stock_Description', 'Nombre_de_titres', 'Cours_du_jour', 'Capitalisation_flottante', 'Capitalisation_globale', 'Capitalisation_globale_pct', 'Date']
# per_data : 98 rows of ['Ticker', 'Stock_Description', 'Nombre_titres_echanges', 'Valeur_echangee', 'PER', 'Valeur_globale_echangee_pct', 'Date']
# stock_prices : 94005 rows of ['Date', 'Ticker', 'Description', 'Open', 'High', 'Low', 'Close', 'Volume']
# indices_performances : 1122 rows of ['Date', 'Ticker', 'Description', 'Open', 'High', 'Low', 'Close', 'Volume']
#
# ######### CLEINSERTION OF TODAY PRICES ###########
#
# Description INDICE SIKAFINANCE not found
# Description SIKA TOTAL RETURN not found
# Description AFRICA GLOBAL LOGISTICS not found
# Description CROWN SIEM not found
# Description MOVIS CI not found
# Description AFRICA GLOBAL LOGISTICS not found
# Unknown columns in stock_prices: {'Variation', 'index'}
# Inserted 64 new daily rows into 'prices' table.
# Table status (rows):
# capitalisations : 0 rows of ['Ticker', 'Stock_Description', 'Nombre_de_titres', 'Cours_du_jour', 'Capitalisation_flottante', 'Capitalisation_globale', 'Capitalisation_globale_pct', 'Date']
# per_data : 98 rows of ['Ticker', 'Stock_Description', 'Nombre_titres_echanges', 'Valeur_echangee', 'PER', 'Valeur_globale_echangee_pct', 'Date']
# stock_prices : 94069 rows of ['Date', 'Ticker', 'Description', 'Open', 'High', 'Low', 'Close', 'Volume']
# indices_performances : 1122 rows of ['Date', 'Ticker', 'Description', 'Open', 'High', 'Low', 'Close', 'Volume']

# %%
def get_close_matrix(self):
    df = self.get_prices()
    return df.pivot(index='Date', columns='Ticker', values='Close')
# Out:
#                    Date Ticker         Description    Open    High     Low  \
# 0   2025-06-10 00:00:00   ABJC  SERVAIR ABIDJAN CI  1710.0  1710.0  1710.0
# 1   2025-06-09 00:00:00   ABJC  SERVAIR ABIDJAN CI  1710.0  1710.0  1710.0
# 2   2025-06-05 00:00:00   ABJC  SERVAIR ABIDJAN CI  1660.0  1660.0  1660.0
# 3   2025-06-04 00:00:00   ABJC  SERVAIR ABIDJAN CI  1600.0  1660.0  1600.0
# 4   2025-06-03 00:00:00   ABJC  SERVAIR ABIDJAN CI  1600.0  1600.0  1600.0
# 5   2025-06-02 00:00:00   ABJC  SERVAIR ABIDJAN CI  1600.0  1600.0  1600.0
# 6   2025-05-30 00:00:00   ABJC  SERVAIR ABIDJAN CI  1600.0  1600.0  1600.0
# 7   2025-05-29 00:00:00   ABJC  SERVAIR ABIDJAN CI  1580.0  1600.0  1580.0
# 8   2025-05-28 00:00:00   ABJC  SERVAIR ABIDJAN CI  1580.0  1600.0  1580.0
# 9   2025-05-27 00:00:00   ABJC  SERVAIR ABIDJAN CI  1580.0  1580.0  1580.0
# 10  2025-05-26 00:00:00   ABJC  SERVAIR ABIDJAN CI  1595.0  1595.0  1580.0
# 11  2025-05-23 00:00:00   ABJC  SERVAIR ABIDJAN CI  1600.0  1600.0  1595.0
# 12  2025-05-22 00:00:00   ABJC  SERVAIR ABIDJAN CI  1525.0  1600.0  1525.0
# 13  2025-05-21 00:00:00   ABJC  SERVAIR ABIDJAN CI  1590.0  1590.0  1525.0
# 14  2025-05-20 00:00:00   ABJC  SERVAIR ABIDJAN CI  1600.0  1600.0  1590.0
# 15  2025-05-19 00:00:00   ABJC  SERVAIR ABIDJAN CI  1605.0  1605.0  1600.0
# 16  2025-05-16 00:00:00   ABJC  SERVAIR ABIDJAN CI  1605.0  1605.0  1605.0
# 17  2025-05-15 00:00:00   ABJC  SERVAIR ABIDJAN CI  1610.0  1610.0  1605.0
# 18  2025-05-14 00:00:00   ABJC  SERVAIR ABIDJAN CI  1610.0  1610.0  1610.0
# 19  2025-05-13 00:00:00   ABJC  SERVAIR ABIDJAN CI  1610.0  1610.0  1610.0
# 20  2025-05-12 00:00:00   ABJC  SERVAIR ABIDJAN CI  1605.0  1610.0  1605.0
# 21  2025-05-09 00:00:00   ABJC  SERVAIR ABIDJAN CI  1610.0  1610.0  1605.0
# 22  2025-05-08 00:00:00   ABJC  SERVAIR ABIDJAN CI  1630.0  1630.0  1610.0
# 23  2025-05-07 00:00:00   ABJC  SERVAIR ABIDJAN CI  1635.0  1635.0  1630.0
# 24  2025-05-06 00:00:00   ABJC  SERVAIR ABIDJAN CI  1635.0  1635.0  1635.0
# 25  2025-05-05 00:00:00   ABJC  SERVAIR ABIDJAN CI  1700.0  1700.0  1635.0
# 26  2025-05-02 00:00:00   ABJC  SERVAIR ABIDJAN CI  1750.0  1750.0  1700.0
#
#      Close   Volume
# 0   1710.0   2420.0
# 1   1710.0   2420.0
# 2   1660.0   6000.0
# 3   1660.0  10000.0
# 4   1600.0   8000.0
# 5   1600.0      0.0
# 6   1600.0   2000.0
# 7   1600.0   1467.0
# 8   1600.0   1000.0
# 9   1580.0   4000.0
# 10  1580.0      0.0
# 11  1595.0   4000.0
# 12  1600.0      0.0
# 13  1525.0   1000.0
# 14  1590.0   1000.0
# 15  1600.0   4000.0
# 16  1605.0      0.0
# 17  1605.0   2000.0
# 18  1610.0      0.0
# 19  1610.0   7000.0
# 20  1610.0   2000.0
# 21  1605.0   1000.0
# 22  1610.0      0.0
# 23  1630.0   1000.0
# 24  1635.0      0.0
# 25  1635.0      0.0
# 26  1700.0   4000.0

# %%
#!pip install PyPDF2

# %%
#db_test.load_available_data()
#db_test.get_prices()
#db_test.insert_today_price()
#db_test.get_prices()
